# %% [markdown]
# # 📈 Ringkasan Visualisasi
#
# - **Histogram usia**: Menunjukkan distribusi umur yang mirip antara kontrol dan perlakuan.
# - **Bar chart proporsi infeksi**: Perlakuan tampak menurunkan infeksi dibanding kontrol.
# - **Countplot gender**: Komposisi gender seimbang, tidak ada dominasi kelompok tertentu.
# - Visualisasi membantu memperjelas perbedaan proporsi dan distribusi antar kelompok.

# %%
# Import fungsi visualisasi
import sys
sys.path.append("..")  # naik satu folder dari notebooks ke root project

from scripts.visualization import (
    plot_age_distribution,
    plot_infection_rate,
    plot_gender_distribution
)

import pandas as pd

# Load data bersih
control_clean = pd.read_csv("../data/processed/control_group_clean.csv")
treatment_clean = pd.read_csv("../data/processed/treatment_group_clean.csv")

# Distribusi usia
plot_age_distribution(control_clean, treatment_clean)

# Proporsi infeksi
plot_infection_rate(control_clean, treatment_clean)

# Distribusi gender
plot_gender_distribution(control_clean, treatment_clean)
