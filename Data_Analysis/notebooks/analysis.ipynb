# %%
import sys
sys.path.append("..") 
from scripts.analysis import (
    load_data,
    clean_data,
    save_processed
)

# %%
load_data()
# Out:
# (     ID    Group  Age  Gender  Infected
#  0     1  Control   34    Male         1
#  1     2  Control   45  Female         0
#  2     3  Control   29    Male         1
#  3     4  Control   52  Female         0
#  4     5  Control   41    Male         0
#  ..  ...      ...  ...     ...       ...
#  95   96  Control   44  Female         1
#  96   97  Control   58    Male         0
#  97   98  Control   31  Female         1
#  98   99  Control   46    Male         0
#  99  100  Control   38  Female         0
#
#  [100 rows x 5 columns],
#       ID      Group  Age  Gender  Infected
#  0     1  Treatment   36  Female         0
#  1     2  Treatment   42    Male         0
#  2     3  Treatment   27  Female         1
#  3     4  Treatment   50    Male         0
#  4     5  Treatment   33  Female         0
#  ..  ...        ...  ...     ...       ...
#  95   96  Treatment   55    Male         0
#  96   97  Treatment   36  Female         0
#  97   98  Treatment   42    Male         0
# ...

# %%
clean_data(control,treatment)
# Out:
# (     ID    Group  Age  Gender  Infected
#  0     1  Control   34    Male         1
#  1     2  Control   45  Female         0
#  2     3  Control   29    Male         1
#  3     4  Control   52  Female         0
#  4     5  Control   41    Male         0
#  ..  ...      ...  ...     ...       ...
#  95   96  Control   44  Female         1
#  96   97  Control   58    Male         0
#  97   98  Control   31  Female         1
#  98   99  Control   46    Male         0
#  99  100  Control   38  Female         0
#
#  [100 rows x 5 columns],
#       ID      Group  Age  Gender  Infected
#  0     1  Treatment   36  Female         0
#  1     2  Treatment   42    Male         0
#  2     3  Treatment   27  Female         1
#  3     4  Treatment   50    Male         0
#  4     5  Treatment   33  Female         0
#  ..  ...        ...  ...     ...       ...
#  95   96  Treatment   55    Male         0
#  96   97  Treatment   36  Female         0
#  97   98  Treatment   42    Male         0
# ...

# %%
save_processed(control,treatment)
